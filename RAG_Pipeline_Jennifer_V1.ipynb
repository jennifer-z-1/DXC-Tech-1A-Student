# %%
# import libraries and packages
import pandas as pd
import numpy as np
import gensim
from docx import Document
import google.cloud.aiplatform
import faiss
import numpy

# %%
from google.cloud import storage
import pdfplumber

def download_blob(bucket_name, source_blob_name, destination_file_name):
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)
    blob = bucket.blob(source_blob_name)
    blob.download_to_filename(destination_file_name)

download_blob('dxc_tech_1a', 'EU AI Act.pdf', 'EU AI Act.pdf')

def extract_text_from_pdf(pdf_path):
    text = ""
    with pdfplumber.open(pdf_path) as pdf:
        for page in pdf.pages:
            text += page.extract_text() + "\n"
    return text

text = extract_text_from_pdf('EU AI Act.pdf')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[12], line 10
#       7     blob = bucket.blob(source_blob_name)
#       8     blob.download_to_filename(destination_file_name)
# ---> 10 download_blob('dxc_tech_1a', 'EU AI Act.pdf', 'EU AI Act.pdf')
#      12 def extract_text_from_pdf(pdf_path):
#      13     text = ""
#
# Cell In[12], line 8, in download_blob(bucket_name, source_blob_name, destination_file_name)
#       6 bucket = storage_client.bucket(bucket_name)
#       7 blob = bucket.blob(source_blob_name)
# ----> 8 blob.download_to_filename(destination_file_name)
#
# File ~\anaconda3\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\google\cloud\storage\blob.py:1345, in Blob.download_to_filename(self, filename, client, start, end, raw_download, if_etag_match, if_etag_not_match, if_generation_match, if_generation_not_match, if_metageneration_match, if_metageneration_not_match, timeout, checksum, retry)
#    1236 @create_trace_span(name="Storage.Blob.downloadToFilename")
#    1237 def download_to_filename(
#    1238     self,
#    (...)
#    1252     retry=DEFAULT_RETRY,
#    1253 ):
#    1254     """Download the contents of this blob into a named file.
#    1255
#    1256     If :attr:`user_project` is set on the bucket, bills the API request
#    (...)
#    1342     :raises: :class:`google.cloud.exceptions.NotFound`
#    1343     """
# -> 1345     self._handle_filename_and_download(
#    1346         filename,
#    1347         client=client,
#    1348         start=start,
#    1349         end=end,
#    1350         raw_download=raw_download,
#    1351         if_etag_match=if_etag_match,
#    1352         if_etag_not_match=if_etag_not_match,
#    1353         if_generation_match=if_generation_match,
#    1354         if_generation_not_match=if_generation_not_match,
#    1355         if_metageneration_match=if_metageneration_match,
#    1356         if_metageneration_not_match=if_metageneration_not_match,
#    1357         timeout=timeout,
#    1358         checksum=checksum,
#    1359         retry=retry,
#    1360     )
#
# File ~\anaconda3\Lib\site-packages\google\cloud\storage\blob.py:1219, in Blob._handle_filename_and_download(self, filename, *args, **kwargs)
#    1210 """Download the contents of this blob into a named file.
#    1211
#    1212 :type filename: str
#    (...)
#    1215 For *args and **kwargs, refer to the documentation for download_to_filename() for more information.
#    1216 """
#    1218 try:
# -> 1219     with open(filename, "wb") as file_obj:
#    1220         self._prep_and_do_download(
#    1221             file_obj,
#    1222             *args,
#    1223             **kwargs,
#    1224         )
#    1226 except resumable_media.DataCorruption:
#    1227     # Delete the corrupt downloaded file.
#
# PermissionError: [Errno 13] Permission denied: 'EU AI Act.pdf'

# %%
# remove unwanted text #
import re

# remove emails
text = re.sub(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,}\b', '', text)

# remove URLs
text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)

# normalize white space
text = re.sub(r'\s+', ' ', text).strip()

# %%
# text tokenization #
from gensim.utils import simple_preprocess

# tokenize the text
tokens = simple_preprocess(text)

# %%
# stop words removal #
from nltk.corpus import stopwords
import nltk

# load built-in stop words
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# remove stop words
tokens = [token for token in tokens if token not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jenni\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# lemmatization #
# !python -m spacy download en_core_web_md
import spacy

# load spacey model
nlp = spacy.load('en_core_web_md')

# lemmatize using spacey
text = ' '.join(tokens)
doc = nlp(text)
tokens = [token.lemma_ for token in doc]
# Out:
# Collecting en-core-web-md==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-3.7.1/en_core_web_md-3.7.1-py3-none-any.whl (42.8 MB)
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/42.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/42.8 MB 330.3 kB/s eta 0:02:10
#      --------------------------------------- 0.1/42.8 MB 409.6 kB/s eta 0:01:45
#      --------------------------------------- 0.1/42.8 MB 654.9 kB/s eta 0:01:06
#      ---------------------------------------- 0.5/42.8 MB 2.2 MB/s eta 0:00:20
#       --------------------------------------- 1.0/42.8 MB 4.0 MB/s eta 0:00:11
#      - -------------------------------------- 2.1/42.8 MB 6.7 MB/s eta 0:00:07
#      --- ------------------------------------ 3.3/42.8 MB 9.6 MB/s eta 0:00:05
#      --- ------------------------------------ 4.0/42.8 MB 10.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 5.2/42.8 MB 11.8 MB/s eta 0:00:04
#      ----- ---------------------------------- 6.2/42.8 MB 12.4 MB/s eta 0:00:03
#      ------ --------------------------------- 7.2/42.8 MB 13.1 MB/s eta 0:00:03
#      ------- -------------------------------- 8.4/42.8 MB 14.1 MB/s eta 0:00:03
#      -------- ------------------------------- 9.3/42.8 MB 14.6 MB/s eta 0:00:03
#      --------- ----------------------------- 10.3/42.8 MB 19.8 MB/s eta 0:00:02
#      ---------- ---------------------------- 11.5/42.8 MB 22.6 MB/s eta 0:00:02
#      ----------- --------------------------- 12.6/42.8 MB 22.6 MB/s eta 0:00:02
#      ------------ -------------------------- 13.6/42.8 MB 22.6 MB/s eta 0:00:02
#      ------------- ------------------------- 14.7/42.8 MB 23.4 MB/s eta 0:00:02
#      -------------- ------------------------ 15.7/42.8 MB 23.4 MB/s eta 0:00:02
#      --------------- ----------------------- 16.8/42.8 MB 22.6 MB/s eta 0:00:02
#      --------------- ----------------------- 17.4/42.8 MB 22.6 MB/s eta 0:00:02
#      ---------------- ---------------------- 18.5/42.8 MB 21.8 MB/s eta 0:00:02
#      ----------------- --------------------- 19.6/42.8 MB 21.8 MB/s eta 0:00:02
#      ------------------ -------------------- 20.6/42.8 MB 21.9 MB/s eta 0:00:02
#      ------------------- ------------------- 21.8/42.8 MB 21.8 MB/s eta 0:00:01
#      -------------------- ------------------ 22.2/42.8 MB 21.9 MB/s eta 0:00:01
#      -------------------- ------------------ 22.2/42.8 MB 21.9 MB/s eta 0:00:01
#      ---------------------- ---------------- 24.5/42.8 MB 21.1 MB/s eta 0:00:01
#      ----------------------- --------------- 25.7/42.8 MB 21.1 MB/s eta 0:00:01
#      ------------------------ -------------- 26.9/42.8 MB 21.8 MB/s eta 0:00:01
#      ------------------------- ------------- 28.0/42.8 MB 23.4 MB/s eta 0:00:01
#      -------------------------- ------------ 29.3/42.8 MB 23.4 MB/s eta 0:00:01
#      --------------------------- ----------- 30.5/42.8 MB 24.2 MB/s eta 0:00:01
#      ---------------------------- ---------- 31.3/42.8 MB 23.4 MB/s eta 0:00:01
#      ----------------------------- --------- 32.6/42.8 MB 28.5 MB/s eta 0:00:01
#      ------------------------------ -------- 33.9/42.8 MB 26.2 MB/s eta 0:00:01
#      ------------------------------- ------- 35.0/42.8 MB 25.1 MB/s eta 0:00:01
#      -------------------------------- ------ 36.2/42.8 MB 25.1 MB/s eta 0:00:01
#      --------------------------------- ----- 36.7/42.8 MB 23.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 38.0/42.8 MB 24.2 MB/s eta 0:00:01
#      ----------------------------------- --- 39.0/42.8 MB 23.4 MB/s eta 0:00:01
#      ------------------------------------ -- 39.8/42.8 MB 23.4 MB/s eta 0:00:01
#      ------------------------------------- - 40.6/42.8 MB 21.8 MB/s eta 0:00:01
#      ------------------------------------- - 41.5/42.8 MB 21.8 MB/s eta 0:00:01
#      --------------------------------------  42.1/42.8 MB 21.1 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 19.8 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 19.8 MB/s eta 0:00:01
#      --------------------------------------  42.8/42.8 MB 19.8 MB/s eta 0:00:01
#      --------------------------------------- 42.8/42.8 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\jenni\anaconda3\lib\site-packages (from en-core-web-md==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.9.0)
# Requirement already satisfied: jinja2 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\jenni\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\jenni\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\jenni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.2 in c:\users\jenni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.23.2)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\jenni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (4.12.2)
# Requirement already satisfied: tzdata in c:\users\jenni\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jenni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jenni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jenni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jenni\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\jenni\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\jenni\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.5)
# Requirement already satisfied: colorama in c:\users\jenni\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\jenni\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\jenni\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jenni\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (13.8.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\jenni\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\jenni\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jenni\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\jenni\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jenni\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jenni\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jenni\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-md==3.7.1) (0.1.0)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %%
import re
from datetime import datetime

def extract_and_categorize_sections(text, keywords):
    # Create regex patterns for different sections
    keyword_patterns = {keyword: re.compile(rf'^({re.escape(keyword)} \d*[:.]?\s.*)', re.MULTILINE) for keyword in keywords}

    # Initialize containers for different sections
    data = {keyword: {"headers": [], "sections": []} for keyword in keywords}

    last_pos = 0

    # Iterate through each keyword pattern to extract sections
    for keyword in keywords:
        pattern = keyword_patterns[keyword]
        matches = pattern.finditer(text)

        for match in matches:
            header = match.group(1)
            start_pos = match.start()
            
            if start_pos > last_pos:
                # Extract text between the last header and the current one
                previous_text = text[last_pos:start_pos].strip()
                
                # Determine which section this text belongs to
                for keyword_check in keywords:
                    if keyword_check in header:
                        data[keyword_check]["sections"].append(previous_text)
                        break
            
            data[keyword]["headers"].append(header)
            last_pos = match.end()
    
    # Add the remaining text after the last header
    if last_pos < len(text):
        remaining_text = text[last_pos:].strip()
        for keyword in keywords:
            if any(keyword in header for header in data[keyword]["headers"]):
                data[keyword]["sections"].append(remaining_text)
                break

    # Add a timestamp
    data["created_at"] = datetime.utcnow().isoformat()
    
    return data

# Define the keywords for headers
keywords = ["chapter", "article", "annex"]

categorized_data = extract_and_categorize_sections(text, keywords)

# Print categorized data for verification
for keyword in keywords:
    print(f"\n{keyword}s:")
    for header, section in zip(categorized_data[keyword]["headers"], categorized_data[keyword]["sections"]):
        print(f"Header: {header}")
        print(f"Section: {section[:500]}...")

# %%
from getpass import getpass
from elasticsearch import Elasticsearch

# Create a connection to Elasticsearch
CLOUD_ID = getpass("Elastic deployment Cloud ID")

CLOUD_PASSWORD = getpass("Elastic deployment Password")

client = Elasticsearch(
  cloud_id = CLOUD_ID,
  basic_auth=("elastic", CLOUD_PASSWORD) # Alternatively use `api_key` instead of `basic_auth`
)

# Test connection to Elasticsearch
print(client.info())
